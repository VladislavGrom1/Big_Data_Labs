# %% [markdown]
# ## Лабораторная работа №1 по СОБД
# ## Выполнение разведочного анализа больших данных с использованием фреймворка Apache Spark
# ## Часть 1
# ## Датасет "NYC Yellow Taxi Trip Data"
# ### Объём: 6.88 Гб

# %% [markdown]
# ## Подключение необходимых библиотек

# %%
from pyspark.sql import SparkSession
from functools import reduce
from pyspark import SparkConf
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import functions as F 
import math

# %% [markdown]
# ## Инициализация PySpark и создание сессии

# %%
conf = SparkConf()
conf.setAppName("Trip Data Analysis")
conf.setMaster("local[*]")  # Локальный режим (все ядра контейнера)
conf.set("spark.hadoop.fs.defaultFS", "hdfs://hadoop-namenode:9820")  # Указываем HDFS
conf.set("spark.driver.memory", "4g")
conf.set("spark.driver.cores", "2")
conf.set("spark.executor.memory", "12g")
conf.set("spark.executor.cores", "8")
conf.set("spark.sql.adaptive.enabled", "true")  # Оптимизация запросов

spark = SparkSession.builder.config(conf=conf).getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://864eda11676d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Trip Data Analysis</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Обзор датасета
# Для исследования используется датасет
# <h3  style=\"text-align:center;\"><a href=\"https://www.kaggle.com/datasets/elemento/nyc-yellow-taxi-trip-data/data\">NYC Yellow Taxi Trip Data</a></h3>

# %% [markdown]
# Датасет уже загружен по адресу "hdfs:///user/vladislav_vaganov/datasets". Датасет состоит из 4-х частей: tripdata_01.csv, tripdata_02.csv, tripdata_03.csv, tripdata_04.csv.
# Определим схему типов данных датасета заранее для экономии вычислительных ресурсов

# %%
schema = StructType([
    StructField("VendorID", IntegerType(), True),                
    StructField("tpep_pickup_datetime", TimestampType(), True),
    StructField("tpep_dropoff_datetime", TimestampType(), True),
    StructField("passenger_count", IntegerType(), True),
    StructField("trip_distance", DoubleType(), True),
    StructField("pickup_longitude", DoubleType(), True),
    StructField("pickup_latitude", DoubleType(), True),
    StructField("RateCodeID", IntegerType(), True),               
    StructField("store_and_fwd_flag", StringType(), True),       
    StructField("dropoff_longitude", DoubleType(), True),
    StructField("dropoff_latitude", DoubleType(), True),
    StructField("payment_type", IntegerType(), True),            
    StructField("fare_amount", DoubleType(), True),
    StructField("extra", DoubleType(), True),
    StructField("mta_tax", DoubleType(), True),
    StructField("tip_amount", DoubleType(), True),
    StructField("tolls_amount", DoubleType(), True),
    StructField("improvement_surcharge", DoubleType(), True),
    StructField("total_amount", DoubleType(), True)
])

# %% [markdown]
# Определим путь до директории датасета

# %%
path = "hdfs:///user/vladislav_vaganov/datasets/"

# %% [markdown]
# Заполним датафрейм данными из директории datasets

# %%
df_combined = spark.read \
    .option("inferSchema", "true") \
    .schema(schema) \
    .csv(path)

# %% [markdown]
# Выведем фрагмент датафрейма на экран

# %%
df_combined.limit(20).toPandas().style\
    .set_properties(**{'text-align': 'left', 'max-width': '0', 'white-space': 'nowrap', 'overflow': 'hidden', 'text-overflow': 'ellipsis'})\
    .set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}])\
    .format(precision=2)
# Out:
# <style type="text/css">
# #T_df3b7 th {
#   text-align: left;
# }
# #T_df3b7_row0_col0, #T_df3b7_row0_col1, #T_df3b7_row0_col2, #T_df3b7_row0_col3, #T_df3b7_row0_col4, #T_df3b7_row0_col5, #T_df3b7_row0_col6, #T_df3b7_row0_col7, #T_df3b7_row0_col8, #T_df3b7_row0_col9, #T_df3b7_row0_col10, #T_df3b7_row0_col11, #T_df3b7_row0_col12, #T_df3b7_row0_col13, #T_df3b7_row0_col14, #T_df3b7_row0_col15, #T_df3b7_row0_col16, #T_df3b7_row0_col17, #T_df3b7_row0_col18, #T_df3b7_row1_col0, #T_df3b7_row1_col1, #T_df3b7_row1_col2, #T_df3b7_row1_col3, #T_df3b7_row1_col4, #T_df3b7_row1_col5, #T_df3b7_row1_col6, #T_df3b7_row1_col7, #T_df3b7_row1_col8, #T_df3b7_row1_col9, #T_df3b7_row1_col10, #T_df3b7_row1_col11, #T_df3b7_row1_col12, #T_df3b7_row1_col13, #T_df3b7_row1_col14, #T_df3b7_row1_col15, #T_df3b7_row1_col16, #T_df3b7_row1_col17, #T_df3b7_row1_col18, #T_df3b7_row2_col0, #T_df3b7_row2_col1, #T_df3b7_row2_col2, #T_df3b7_row2_col3, #T_df3b7_row2_col4, #T_df3b7_row2_col5, #T_df3b7_row2_col6, #T_df3b7_row2_col7, #T_df3b7_row2_col8, #T_df3b7_row2_col9, #T_df3b7_row2_col10, #T_df3b7_row2_col11, #T_df3b7_row2_col12, #T_df3b7_row2_col13, #T_df3b7_row2_col14, #T_df3b7_row2_col15, #T_df3b7_row2_col16, #T_df3b7_row2_col17, #T_df3b7_row2_col18, #T_df3b7_row3_col0, #T_df3b7_row3_col1, #T_df3b7_row3_col2, #T_df3b7_row3_col3, #T_df3b7_row3_col4, #T_df3b7_row3_col5, #T_df3b7_row3_col6, #T_df3b7_row3_col7, #T_df3b7_row3_col8, #T_df3b7_row3_col9, #T_df3b7_row3_col10, #T_df3b7_row3_col11, #T_df3b7_row3_col12, #T_df3b7_row3_col13, #T_df3b7_row3_col14, #T_df3b7_row3_col15, #T_df3b7_row3_col16, #T_df3b7_row3_col17, #T_df3b7_row3_col18, #T_df3b7_row4_col0, #T_df3b7_row4_col1, #T_df3b7_row4_col2, #T_df3b7_row4_col3, #T_df3b7_row4_col4, #T_df3b7_row4_col5, #T_df3b7_row4_col6, #T_df3b7_row4_col7, #T_df3b7_row4_col8, #T_df3b7_row4_col9, #T_df3b7_row4_col10, #T_df3b7_row4_col11, #T_df3b7_row4_col12, #T_df3b7_row4_col13, #T_df3b7_row4_col14, #T_df3b7_row4_col15, #T_df3b7_row4_col16, #T_df3b7_row4_col17, #T_df3b7_row4_col18, #T_df3b7_row5_col0, #T_df3b7_row5_col1, #T_df3b7_row5_col2, #T_df3b7_row5_col3, #T_df3b7_row5_col4, #T_df3b7_row5_col5, #T_df3b7_row5_col6, #T_df3b7_row5_col7, #T_df3b7_row5_col8, #T_df3b7_row5_col9, #T_df3b7_row5_col10, #T_df3b7_row5_col11, #T_df3b7_row5_col12, #T_df3b7_row5_col13, #T_df3b7_row5_col14, #T_df3b7_row5_col15, #T_df3b7_row5_col16, #T_df3b7_row5_col17, #T_df3b7_row5_col18, #T_df3b7_row6_col0, #T_df3b7_row6_col1, #T_df3b7_row6_col2, #T_df3b7_row6_col3, #T_df3b7_row6_col4, #T_df3b7_row6_col5, #T_df3b7_row6_col6, #T_df3b7_row6_col7, #T_df3b7_row6_col8, #T_df3b7_row6_col9, #T_df3b7_row6_col10, #T_df3b7_row6_col11, #T_df3b7_row6_col12, #T_df3b7_row6_col13, #T_df3b7_row6_col14, #T_df3b7_row6_col15, #T_df3b7_row6_col16, #T_df3b7_row6_col17, #T_df3b7_row6_col18, #T_df3b7_row7_col0, #T_df3b7_row7_col1, #T_df3b7_row7_col2, #T_df3b7_row7_col3, #T_df3b7_row7_col4, #T_df3b7_row7_col5, #T_df3b7_row7_col6, #T_df3b7_row7_col7, #T_df3b7_row7_col8, #T_df3b7_row7_col9, #T_df3b7_row7_col10, #T_df3b7_row7_col11, #T_df3b7_row7_col12, #T_df3b7_row7_col13, #T_df3b7_row7_col14, #T_df3b7_row7_col15, #T_df3b7_row7_col16, #T_df3b7_row7_col17, #T_df3b7_row7_col18, #T_df3b7_row8_col0, #T_df3b7_row8_col1, #T_df3b7_row8_col2, #T_df3b7_row8_col3, #T_df3b7_row8_col4, #T_df3b7_row8_col5, #T_df3b7_row8_col6, #T_df3b7_row8_col7, #T_df3b7_row8_col8, #T_df3b7_row8_col9, #T_df3b7_row8_col10, #T_df3b7_row8_col11, #T_df3b7_row8_col12, #T_df3b7_row8_col13, #T_df3b7_row8_col14, #T_df3b7_row8_col15, #T_df3b7_row8_col16, #T_df3b7_row8_col17, #T_df3b7_row8_col18, #T_df3b7_row9_col0, #T_df3b7_row9_col1, #T_df3b7_row9_col2, #T_df3b7_row9_col3, #T_df3b7_row9_col4, #T_df3b7_row9_col5, #T_df3b7_row9_col6, #T_df3b7_row9_col7, #T_df3b7_row9_col8, #T_df3b7_row9_col9, #T_df3b7_row9_col10, #T_df3b7_row9_col11, #T_df3b7_row9_col12, #T_df3b7_row9_col13, #T_df3b7_row9_col14, #T_df3b7_row9_col15, #T_df3b7_row9_col16, #T_df3b7_row9_col17, #T_df3b7_row9_col18, #T_df3b7_row10_col0, #T_df3b7_row10_col1, #T_df3b7_row10_col2, #T_df3b7_row10_col3, #T_df3b7_row10_col4, #T_df ...

# %% [markdown]
# ## Описание столбцов датасета
#
# | Название столбца | Тип данных | Расшифровка |
# |:----------------:|:----------:|:------------|
# | VendorID | integer | Идентификатор провайдера телематических данных |
# | tpep_pickup_datetime | timestamp | Дата и время посадки пассажира в такси |
# | tpep_dropoff_datetime | timestamp | Дата и время высадки пассажира из такси |
# | passenger_count | integer | Количество пассажиров в такси |
# | trip_distance | double | Расстояние поездки в милях по счетчику такси |
# | pickup_longitude | double | Географические координаты места посадки (долгота) |
# | pickup_latitude | double | Географические координаты места посадки (широта) |
# | RateCodeID | integer | Код типа тарифа |
# | store_and_fwd_flag | string | Технический флаг хранения данных в буфере |
# | dropoff_longitude | double | Географические координаты места высадки (долгота) |
# | dropoff_latitude | double | Географические координаты места высадки (широта) |
# | payment_type | integer | Способ оплаты поездки |
# | fare_amount | double | Основная стоимость поездки (базовый тариф + расстояние) |
# | extra | double | Дополнительные сборы и надбавки |
# | mta_tax | double | Налог Metropolitan Transportation Authority |
# | tip_amount | double | Сумма чаевых водителю |
# | tolls_amount | double | Стоимость платных дорог, мостов, туннелей |
# | improvement_surcharge | double | Сбор на улучшение сервиса такси |
# | total_amount | double | Итоговая сумма к оплате |вая сумма к оплате |говая сумма к оплате ||  Row 4   |   |ка автомобиля |"ка автомобиля |"

# %% [markdown]
# Преобразуем датафрейм

# %% [markdown]
# ### Оставленные столбцы

# %% [markdown]
# | Название столбца        | Тип данных  | Расшифровка                                                                 | Комментарий |
# |:------------------------|:------------|:----------------------------------------------------------------------------|:------------|
# | `VendorID`              | integer     | Идентификатор провайдера данных                              | Может отражать различия в тарифах между компаниями |
# | `tpep_pickup_datetime`  | timestamp   | Дата и время посадки пассажира в такси                                      | - |
# | `passenger_count`       | integer     | Количество пассажиров в такси                                               | Может влиять на тариф |
# | `trip_distance`         | double      | Расстояние поездки в милях по счетчику такси                                | Один из главных факторов стоимости |
# | `pickup_longitude`      | double      | Географические координаты места посадки (долгота)                           | Позволяет определить стартовую зону |
# | `pickup_latitude`       | double      | Географические координаты места посадки (широта)                            | Позволяет определить стартовую зону |
# | `dropoff_longitude`     | double      | Географические координаты места высадки (долгота)                           | Позволяет оценить направление и конечную зону |
# | `dropoff_latitude`      | double      | Географические координаты места высадки (широта)                            | Позволяет оценить направление и конечную зону |
# | `RateCodeID`            | integer     | Код типа тарифа                                                             | Напрямую определяет базовую ставку |
# | `payment_type`          | integer     | Способ оплаты поездки                                                       | - |
# | `total_amount`          | integer     | Итоговая стоимость поездки                                                       | Целевая переменная |
#
# ---
#
# ### Исключённые столбцы
#
# | Столбец                 | Причина исключения |
# |:------------------------|:-------------------|
# | `tpep_dropoff_datetime` | Известен только после поездки нельзя использовать при прогнозе |
# | `store_and_fwd_flag`    | Технический флаг, не влияет на стоимость |
# | `fare_amount`           | Часть `total_amount` |
# | `extra`                 | Может включать постфактум-сборы; лучше не использовать без чёткой логики |
# | `mta_tax`               | Константа |
# | `tip_amount`            | Устанавливается пассажиром после поездки недоступно заранее |
# | `tolls_amount`          | Зависит от фактического маршрута неизвестно до поездки |
# | `improvement_surcharge` | Константа |

# %% [markdown]
# Исключим из датафрейма выбранные столбцы

# %%
df_combined = df_combined.select(
    "VendorID", "tpep_pickup_datetime", "passenger_count", "trip_distance", "pickup_longitude", "pickup_latitude",
    "dropoff_longitude", "dropoff_latitude", "RateCodeID", "payment_type",
    "total_amount")

# %%
df_combined.limit(20).toPandas().style\
    .set_properties(**{'text-align': 'left', 'max-width': '0', 'white-space': 'nowrap', 'overflow': 'hidden', 'text-overflow': 'ellipsis'})\
    .set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}])\
    .format(precision=2)
# Out:
# <style type="text/css">
# #T_99176 th {
#   text-align: left;
# }
# #T_99176_row0_col0, #T_99176_row0_col1, #T_99176_row0_col2, #T_99176_row0_col3, #T_99176_row0_col4, #T_99176_row0_col5, #T_99176_row0_col6, #T_99176_row0_col7, #T_99176_row0_col8, #T_99176_row0_col9, #T_99176_row0_col10, #T_99176_row1_col0, #T_99176_row1_col1, #T_99176_row1_col2, #T_99176_row1_col3, #T_99176_row1_col4, #T_99176_row1_col5, #T_99176_row1_col6, #T_99176_row1_col7, #T_99176_row1_col8, #T_99176_row1_col9, #T_99176_row1_col10, #T_99176_row2_col0, #T_99176_row2_col1, #T_99176_row2_col2, #T_99176_row2_col3, #T_99176_row2_col4, #T_99176_row2_col5, #T_99176_row2_col6, #T_99176_row2_col7, #T_99176_row2_col8, #T_99176_row2_col9, #T_99176_row2_col10, #T_99176_row3_col0, #T_99176_row3_col1, #T_99176_row3_col2, #T_99176_row3_col3, #T_99176_row3_col4, #T_99176_row3_col5, #T_99176_row3_col6, #T_99176_row3_col7, #T_99176_row3_col8, #T_99176_row3_col9, #T_99176_row3_col10, #T_99176_row4_col0, #T_99176_row4_col1, #T_99176_row4_col2, #T_99176_row4_col3, #T_99176_row4_col4, #T_99176_row4_col5, #T_99176_row4_col6, #T_99176_row4_col7, #T_99176_row4_col8, #T_99176_row4_col9, #T_99176_row4_col10, #T_99176_row5_col0, #T_99176_row5_col1, #T_99176_row5_col2, #T_99176_row5_col3, #T_99176_row5_col4, #T_99176_row5_col5, #T_99176_row5_col6, #T_99176_row5_col7, #T_99176_row5_col8, #T_99176_row5_col9, #T_99176_row5_col10, #T_99176_row6_col0, #T_99176_row6_col1, #T_99176_row6_col2, #T_99176_row6_col3, #T_99176_row6_col4, #T_99176_row6_col5, #T_99176_row6_col6, #T_99176_row6_col7, #T_99176_row6_col8, #T_99176_row6_col9, #T_99176_row6_col10, #T_99176_row7_col0, #T_99176_row7_col1, #T_99176_row7_col2, #T_99176_row7_col3, #T_99176_row7_col4, #T_99176_row7_col5, #T_99176_row7_col6, #T_99176_row7_col7, #T_99176_row7_col8, #T_99176_row7_col9, #T_99176_row7_col10, #T_99176_row8_col0, #T_99176_row8_col1, #T_99176_row8_col2, #T_99176_row8_col3, #T_99176_row8_col4, #T_99176_row8_col5, #T_99176_row8_col6, #T_99176_row8_col7, #T_99176_row8_col8, #T_99176_row8_col9, #T_99176_row8_col10, #T_99176_row9_col0, #T_99176_row9_col1, #T_99176_row9_col2, #T_99176_row9_col3, #T_99176_row9_col4, #T_99176_row9_col5, #T_99176_row9_col6, #T_99176_row9_col7, #T_99176_row9_col8, #T_99176_row9_col9, #T_99176_row9_col10, #T_99176_row10_col0, #T_99176_row10_col1, #T_99176_row10_col2, #T_99176_row10_col3, #T_99176_row10_col4, #T_99176_row10_col5, #T_99176_row10_col6, #T_99176_row10_col7, #T_99176_row10_col8, #T_99176_row10_col9, #T_99176_row10_col10, #T_99176_row11_col0, #T_99176_row11_col1, #T_99176_row11_col2, #T_99176_row11_col3, #T_99176_row11_col4, #T_99176_row11_col5, #T_99176_row11_col6, #T_99176_row11_col7, #T_99176_row11_col8, #T_99176_row11_col9, #T_99176_row11_col10, #T_99176_row12_col0, #T_99176_row12_col1, #T_99176_row12_col2, #T_99176_row12_col3, #T_99176_row12_col4, #T_99176_row12_col5, #T_99176_row12_col6, #T_99176_row12_col7, #T_99176_row12_col8, #T_99176_row12_col9, #T_99176_row12_col10, #T_99176_row13_col0, #T_99176_row13_col1, #T_99176_row13_col2, #T_99176_row13_col3, #T_99176_row13_col4, #T_99176_row13_col5, #T_99176_row13_col6, #T_99176_row13_col7, #T_99176_row13_col8, #T_99176_row13_col9, #T_99176_row13_col10, #T_99176_row14_col0, #T_99176_row14_col1, #T_99176_row14_col2, #T_99176_row14_col3, #T_99176_row14_col4, #T_99176_row14_col5, #T_99176_row14_col6, #T_99176_row14_col7, #T_99176_row14_col8, #T_99176_row14_col9, #T_99176_row14_col10, #T_99176_row15_col0, #T_99176_row15_col1, #T_99176_row15_col2, #T_99176_row15_col3, #T_99176_row15_col4, #T_99176_row15_col5, #T_99176_row15_col6, #T_99176_row15_col7, #T_99176_row15_col8, #T_99176_row15_col9, #T_99176_row15_col10, #T_99176_row16_col0, #T_99176_row16_col1, #T_99176_row16_col2, #T_99176_row16_col3, #T_99176_row16_col4, #T_99176_row16_col5, #T_99176_row16_col6, #T_99176_row16_col7, #T_99176_row16_col8, #T_99176_row16_col9, #T_99176_row16_col10, #T_99176_row17_col0, #T_99176_row17_col1, #T_99176_row17_col2, #T_99176_row17_col3, #T_99176_row17_col4, #T_99176_row17_col5, #T_99176_row17_col6, #T_99176_row17_col7 ...
#   text-align: left;
#   max-width: 0;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# </style>
# <table id="T_99176">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99176_level0_col0" class="col_heading level0 col0" >VendorID</th>
#       <th id="T_99176_level0_col1" class="col_heading level0 col1" >tpep_pickup_datetime</th>
#       <th id="T_99176_level0_col2" class="col_heading level0 col2" >passenger_count</th>
#       <th id="T_99176_level0_col3" class="col_heading level0 col3" >trip_distance</th>
#       <th id="T_99176_level0_col4" class="col_heading level0 col4" >pickup_longitude</th>
#       <th id="T_99176_level0_col5" class="col_heading level0 col5" >pickup_latitude</th>
#       <th id="T_99176_level0_col6" class="col_heading level0 col6" >dropoff_longitude</th>
#       <th id="T_99176_level0_col7" class="col_heading level0 col7" >dropoff_latitude</th>
#       <th id="T_99176_level0_col8" class="col_heading level0 col8" >RateCodeID</th>
#       <th id="T_99176_level0_col9" class="col_heading level0 col9" >payment_type</th>
#       <th id="T_99176_level0_col10" class="col_heading level0 col10" >total_amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99176_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99176_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_99176_row0_col1" class="data row0 col1" >NaT</td>
#       <td id="T_99176_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_99176_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_99176_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_99176_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_99176_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_99176_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_99176_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_99176_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_99176_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_99176_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99176_row1_col0" class="data row1 col0" >2.00</td>
#       <td id="T_99176_row1_col1" class="data row1 col1" >2015-01-15 19:05:39</td>
#       <td id="T_99176_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_99176_row1_col3" class="data row1 col3" >1.59</td>
#       <td id="T_99176_row1_col4" class="data row1 col4" >-73.99</td>
#       <td id="T_99176_row1_col5" class="data row1 col5" >40.75</td>
#       <td id="T_99176_row1_col6" class="data row1 col6" >-73.97</td>
#       <td id="T_99176_row1_col7" class="data row1 col7" >40.75</td>
#       <td id="T_99176_row1_col8" class="data row1 col8" >1.00</td>
#       <td id="T_99176_row1_col9" class="data row1 col9" >1.00</td>
#       <td id="T_99176_row1_col10" class="data row1 col10" >17.05</td>
#     </tr>
#     <tr>
#       <th id="T_99176_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99176_row2_col0" class="data row2 col0" >1.00</td>
#       <td id="T_99176_row2_col1" class="data row2 col1" >2015-01-10 20:33:38</td>
#       <td id="T_99176_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_99176_row2_col3" class="data row2 col3" >3.30</td>
#       <td id="T_99176_row2_col4" class="data row2 col4" >-74.00</td>
#       <td id="T_99176_row2_col5" class="data row2 col5" >40.72</td>
#       <td id="T_99176_row2

# %% [markdown]
# Выведем метаданные датасета

# %%
df_combined.printSchema()
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp (nullable = true)
#  |-- passenger_count: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- pickup_longitude: double (nullable = true)
#  |-- pickup_latitude: double (nullable = true)
#  |-- dropoff_longitude: double (nullable = true)
#  |-- dropoff_latitude: double (nullable = true)
#  |-- RateCodeID: integer (nullable = true)
#  |-- payment_type: integer (nullable = true)
#  |-- total_amount: double (nullable = true)

# %% [markdown]
# ## Преобразования датасета

# %% [markdown]
# В полученном датафрейме есть географические признаки широты и долготы посадки/высадки пассажиров. Выполним следующие преобразования:

# %% [markdown]
# 1. Согласно формуле Хаверсина вычислим расстояние между точками посадки/высадки пассажиров на поверхности сферы по широте и долготе.

# %%
def haversine_miles(lat1, lon1, lat2, lon2):
    R = 3958.8
    lat1_rad = F.radians(lat1)
    lon1_rad = F.radians(lon1)
    lat2_rad = F.radians(lat2)
    lon2_rad = F.radians(lon2)
    dlat = lat2_rad - lat1_rad
    dlon = lon2_rad - lon1_rad
    a = F.sin(dlat / 2)**2 + F.cos(lat1_rad) * F.cos(lat2_rad) * F.sin(dlon / 2)**2
    c = 2 * F.atan2(F.sqrt(a), F.sqrt(1 - a))
    return R * c

df_with_distance = df_combined.withColumn(
    "haversine_distance",
    haversine_miles(
        F.col("pickup_latitude"), F.col("pickup_longitude"),
        F.col("dropoff_latitude"), F.col("dropoff_longitude")
    )
)

# %% [markdown]
# 2. Определим константы координаты аэропортов в Нью-Йорке для того, чтобы ввести в датафрейм признак, определяющий была ли поездка начата/закончена в области аэропортов

# %%
# Координаты аэропортов Нью-Йорка
JFK_LONG, JFK_LAT = -73.78222222, 40.64416667
LGA_LONG, LGA_LAT = -73.87388889, 40.77694444
EWR_LONG, EWR_LAT = -74.17472222, 40.68972222
AIRPORT_RADIUS_MILES = 0.9  # область аэропорта

# %% [markdown]
# Рассчитаем признак "is_airport_trip" для датафрейма:

# %%
# Добавляем флаг is_airport_trip
df_with_airports = df_with_distance.withColumn(
    "is_airport_trip",
    F.when(
        (haversine_miles(F.col("pickup_latitude"), F.col("pickup_longitude"), F.lit(JFK_LAT), F.lit(JFK_LONG)) <= AIRPORT_RADIUS_MILES) |
        (haversine_miles(F.col("dropoff_latitude"), F.col("dropoff_longitude"), F.lit(JFK_LAT), F.lit(JFK_LONG)) <= AIRPORT_RADIUS_MILES) |
        (haversine_miles(F.col("pickup_latitude"), F.col("pickup_longitude"), F.lit(LGA_LAT), F.lit(LGA_LONG)) <= AIRPORT_RADIUS_MILES) |
        (haversine_miles(F.col("dropoff_latitude"), F.col("dropoff_longitude"), F.lit(LGA_LAT), F.lit(LGA_LONG)) <= AIRPORT_RADIUS_MILES) |
        (haversine_miles(F.col("pickup_latitude"), F.col("pickup_longitude"), F.lit(EWR_LAT), F.lit(EWR_LONG)) <= AIRPORT_RADIUS_MILES) |
        (haversine_miles(F.col("dropoff_latitude"), F.col("dropoff_longitude"), F.lit(EWR_LAT), F.lit(EWR_LONG)) <= AIRPORT_RADIUS_MILES),
        1
    ).otherwise(0)
)

# %% [markdown]
# 3. Обработаем признак "tpep_pickup_datetime". Рассчитаем из него следующие признаки: "pickup_hour" (час посадки), "pickup_dow" (день недели).

# %%
df_with_time_features = df_with_airports \
    .withColumn("pickup_hour", F.hour("tpep_pickup_datetime")) \
    .withColumn("pickup_dow", F.dayofweek("tpep_pickup_datetime"))

# %% [markdown]
# Исключим лишние столбцы после преобразований и приведём датафрейм к следующей структуре:

# %% [markdown]
# | Название столбца        | Тип данных  | Расшифровка                                                                 |
# |:------------------------|:------------|:----------------------------------------------------------------------------|
# | `VendorID`              | integer     | Идентификатор провайдера телематических данных                              |
# | `passenger_count`       | integer     | Количество пассажиров                                                       |
# | `trip_distance`         | double      | Фактическое расстояние поездки в милях                                      |
# | `haversine_distance`    | double      | Расстояние по прямой между посадкой и высадкой (в милях)                    |
# | `RateCodeID`            | integer     | Код типа тарифа                                                             |
# | `payment_type`          | integer     | Способ оплаты                                                               |
# | `is_airport_trip`       | integer     | Флаг поездки в/из аэропорта (1 = да, 0 = нет)                               |
# | `pickup_hour`           | integer     | Час посадки (0–23)                                                          |
# | `pickup_dow`            | integer     | День недели (1 = воскресенье, ..., 7 = суббота)                             |
# | `total_amount`          | double      | Итоговая сумма к оплате

# %%
df_transformed = df_with_time_features.select(
    "VendorID", "passenger_count", "trip_distance", "haversine_distance","RateCodeID", "payment_type", "is_airport_trip", 
    "pickup_hour", "pickup_dow", "total_amount")

df_transformed.show()

row_count = df_combined.count()
print(f"Количество строк: {row_count}")
# Out:
# +--------+---------------+-------------+-------------------+----------+------------+---------------+-----------+----------+------------+
# |VendorID|passenger_count|trip_distance| haversine_distance|RateCodeID|payment_type|is_airport_trip|pickup_hour|pickup_dow|total_amount|
# +--------+---------------+-------------+-------------------+----------+------------+---------------+-----------+----------+------------+
# |    NULL|           NULL|         NULL|               NULL|      NULL|        NULL|              0|       NULL|      NULL|        NULL|
# |       2|              1|         1.59| 1.0009738583401306|         1|           1|              0|         19|         5|       17.05|
# |       1|              1|          3.3|  2.438630505784401|         1|           1|              0|         20|         7|        17.8|
# |       1|              1|          1.8| 1.6110715418320922|         1|           2|              0|         20|         7|        10.8|
# |       1|              1|          0.5| 0.4937643973001886|         1|           2|              0|         20|         7|         4.8|
# |       1|              1|          3.0|  2.202553315919436|         1|           2|              0|         20|         7|        16.3|
# |       1|              1|          9.0|  5.993491432305092|         1|           1|              1|         20|         7|       40.33|
# |       1|              1|          2.2| 1.7017874510807927|         1|           2|              0|         20|         7|        15.3|
# |       1|              3|          0.8| 0.6724567910896615|         1|           1|              0|         20|         7|        9.96|
# |       1|              3|         18.2| 13.339471775732788|         2|           2|              1|         20|         7|       58.13|
# |       1|              2|          0.9| 0.5932878290407552|         1|           1|              0|         20|         7|        9.35|
# |       1|              1|          0.9| 0.9088341373991127|         1|           1|              0|         20|         7|        9.96|
# |       1|              1|          1.1|  1.437414206097876|         1|           1|              0|         20|         7|         9.8|
# |       1|              1|          0.3|0.24293878732492827|         1|           2|              0|         20|         7|         4.3|
# |       1|              1|          3.1|  2.130977582800855|         1|           1|              0|         20|         7|        23.3|
# |       1|              1|          1.1|  0.823048459985655|         1|           2|              0|         20|         7|         7.3|
# |       2|              1|         2.38| 1.3101499000786612|         1|           1|              0|         19|         5|       22.68|
# |       2|              5|         2.83| 2.3626842371594776|         1|           2|              0|         19|         5|        14.3|
# |       2|              5|         8.33|  4.822492767497721|         1|           1|              1|         19|         5|       41.21|
# |       2|              1|         2.37| 1.9037296004917983|         1|           1|              0|         19|         5|        13.3|
# +--------+---------------+-------------+-------------------+----------+------------+---------------+-----------+----------+------------+
# only showing top 20 rows
#
# Количество строк: 47248849

# %% [markdown]
# Сохраним получившийся датафрейм в виде формата Parquet

# %% [markdown]
# Определим путь до директории паркет файлов

# %%
path_output = "hdfs:///user/vladislav_vaganov/datasets/parquets/tripdata_transformed.parquet"

# %% [markdown]
# Сохраним датафрейм в виде файла "tripdata_transformed.parquet"

# %%
df_transformed.write \
    .mode("overwrite") \
    .option("compression", "snappy") \
    .parquet(path_output)

# %% [markdown]
# Останавливаем spark-сессию

# %%
spark.stop()
